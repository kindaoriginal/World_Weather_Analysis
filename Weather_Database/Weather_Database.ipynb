# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e09726b41590f00ec9484c68c372f777

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(1)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]  
        city_dscript = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_dscript})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | baker city
# Processing Record 4 of Set 1 | ismailia
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | boguchany
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | havoysund
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | brae
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | ancud
# Processing Record 17 of Set 1 | tasiilaq
# Processing Record 18 of Set 1 | mizdah
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | prince rupert
# Processing Record 21 of Set 1 | tual
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | shingu
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | tilichiki
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | sitka
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | iwanai
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | kempsey
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | mahon
# Processing Record 40 of Set 1 | sola
# Processing Record 41 of Set 1 | klaksvik
# Processing Record 42 of Set 1 | provideniya
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | saldanha
# Processing Record 45 of Set 1 | esperance
# Processing Record 46 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 1 | betioky
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | grindavik
# Processing Record 50 of Set 1 | chihuahua
# Processing Record 1 of Set 2 | mondlo
# Processing Record 2 of Set 2 | aklavik
# Processing Record 3 of Set 2 | gejiu
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 2 | nacala
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | pooler
# Processing Record 11 of Set 2 | kirakira
# Processing Record 12 of Set 2 | ostrovnoy
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | araouane
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | devarkonda
# Processing Record 18 of Set 2 | brasileia
# Processing Record 19 of Set 2 | abu samrah
# Processing Record 20 of Set 2 | burica
# City not found. Skipping...
# Processing Record 21 of Set 2 | kutum
# Processing Record 22 of Set 2 | hambantota
# Processing Record 23 of Set 2 | cherskiy
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | kargat
# Processing Record 26 of Set 2 | dingle
# Processing Record 27 of Set 2 | cayenne
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | yerofey pavlovich
# Processing Record 30 of Set 2 | los llanos de aridane
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | muros
# Processing Record 33 of Set 2 | moron
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | kalmunai
# Processing Record 37 of Set 2 | acapulco
# Processing Record 38 of Set 2 | didwana
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | adrar
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | luang prabang
# Processing Record 43 of Set 2 | calgary
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | guerrero negro
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | oyama
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | puerto escondido
# Processing Record 1 of Set 3 | emilio carranza
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | formosa
# Processing Record 4 of Set 3 | nouakchott
# Processing Record 5 of Set 3 | itzehoe
# Processing Record 6 of Set 3 | ewa beach
# Processing Record 7 of Set 3 | burnie
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | simand
# Processing Record 10 of Set 3 | pevek
# Processing Record 11 of Set 3 | rudarpur
# Processing Record 12 of Set 3 | sungaipenuh
# Processing Record 13 of Set 3 | camacha
# Processing Record 14 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 3 | praya
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | lindi
# Processing Record 18 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 3 | bethel
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | bolekhiv
# Processing Record 22 of Set 3 | goure
# Processing Record 23 of Set 3 | northam
# Processing Record 24 of Set 3 | puerto ayacucho
# Processing Record 25 of Set 3 | katsuura
# Processing Record 26 of Set 3 | marratxi
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | rio cuarto
# Processing Record 29 of Set 3 | narsaq
# Processing Record 30 of Set 3 | mahebourg
# Processing Record 31 of Set 3 | saint-paul
# Processing Record 32 of Set 3 | olafsvik
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | inhambane
# Processing Record 35 of Set 3 | armizonskoye
# Processing Record 36 of Set 3 | sibolga
# Processing Record 37 of Set 3 | the valley
# Processing Record 38 of Set 3 | clyde river
# Processing Record 39 of Set 3 | alpena
# Processing Record 40 of Set 3 | avarua
# Processing Record 41 of Set 3 | pipraich
# Processing Record 42 of Set 3 | dunedin
# Processing Record 43 of Set 3 | lufilufi
# Processing Record 44 of Set 3 | port keats
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | saint-joseph
# Processing Record 47 of Set 3 | isangel
# Processing Record 48 of Set 3 | khuzhir
# Processing Record 49 of Set 3 | piacabucu
# Processing Record 50 of Set 3 | constitucion
# Processing Record 1 of Set 4 | christchurch
# Processing Record 2 of Set 4 | bella union
# Processing Record 3 of Set 4 | saint anthony
# Processing Record 4 of Set 4 | korla
# Processing Record 5 of Set 4 | coracao de jesus
# Processing Record 6 of Set 4 | pangnirtung
# Processing Record 7 of Set 4 | lhuntshi
# City not found. Skipping...
# Processing Record 8 of Set 4 | luau
# Processing Record 9 of Set 4 | bose
# Processing Record 10 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 4 | manfredonia
# Processing Record 12 of Set 4 | luga
# Processing Record 13 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | isla mujeres
# Processing Record 16 of Set 4 | anadyr
# Processing Record 17 of Set 4 | senador jose porfirio
# Processing Record 18 of Set 4 | fukue
# Processing Record 19 of Set 4 | kodiak
# Processing Record 20 of Set 4 | kisangani
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | victoria
# Processing Record 23 of Set 4 | placido de castro
# Processing Record 24 of Set 4 | la rioja
# Processing Record 25 of Set 4 | okha
# Processing Record 26 of Set 4 | solano
# Processing Record 27 of Set 4 | leshukonskoye
# Processing Record 28 of Set 4 | torbay
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | westport
# Processing Record 31 of Set 4 | norman wells
# Processing Record 32 of Set 4 | pangody
# Processing Record 33 of Set 4 | cordoba
# Processing Record 34 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 4 | udachnyy
# Processing Record 37 of Set 4 | quzhou
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | buala
# Processing Record 40 of Set 4 | belmonte
# Processing Record 41 of Set 4 | nuuk
# Processing Record 42 of Set 4 | valparaiso
# Processing Record 43 of Set 4 | gat
# Processing Record 44 of Set 4 | galle
# Processing Record 45 of Set 4 | kaitangata
# Processing Record 46 of Set 4 | takoradi
# Processing Record 47 of Set 4 | whitehorse
# Processing Record 48 of Set 4 | paracatu
# Processing Record 49 of Set 4 | paamiut
# Processing Record 50 of Set 4 | beloha
# Processing Record 1 of Set 5 | pasighat
# Processing Record 2 of Set 5 | tortoli
# Processing Record 3 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 5 | betafo
# Processing Record 5 of Set 5 | outlook
# Processing Record 6 of Set 5 | bilibino
# Processing Record 7 of Set 5 | sioux lookout
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | srednekolymsk
# Processing Record 10 of Set 5 | gilgit
# Processing Record 11 of Set 5 | elat
# Processing Record 12 of Set 5 | nhulunbuy
# Processing Record 13 of Set 5 | sao filipe
# Processing Record 14 of Set 5 | lensk
# Processing Record 15 of Set 5 | touros
# Processing Record 16 of Set 5 | yangjiang
# Processing Record 17 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 18 of Set 5 | marsh harbour
# Processing Record 19 of Set 5 | ahuimanu
# Processing Record 20 of Set 5 | verkhnevilyuysk
# Processing Record 21 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | batemans bay
# Processing Record 23 of Set 5 | mount isa
# Processing Record 24 of Set 5 | pahrump
# Processing Record 25 of Set 5 | beni
# Processing Record 26 of Set 5 | caceres
# Processing Record 27 of Set 5 | kidal
# Processing Record 28 of Set 5 | tukums
# Processing Record 29 of Set 5 | sept-iles
# Processing Record 30 of Set 5 | georgetown
# Processing Record 31 of Set 5 | peniche
# Processing Record 32 of Set 5 | van
# Processing Record 33 of Set 5 | labuhan
# Processing Record 34 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 5 | sur
# Processing Record 37 of Set 5 | coahuayana
# Processing Record 38 of Set 5 | rafai
# Processing Record 39 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 40 of Set 5 | havelock
# Processing Record 41 of Set 5 | cap malheureux
# Processing Record 42 of Set 5 | bilma
# Processing Record 43 of Set 5 | stokke
# Processing Record 44 of Set 5 | salalah
# Processing Record 45 of Set 5 | pierre
# Processing Record 46 of Set 5 | lavrentiya
# Processing Record 47 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 5 | acarau
# Processing Record 50 of Set 5 | poum
# Processing Record 1 of Set 6 | svetlaya
# Processing Record 2 of Set 6 | namatanai
# Processing Record 3 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 6 | iralaya
# Processing Record 5 of Set 6 | coihaique
# Processing Record 6 of Set 6 | deputatskiy
# Processing Record 7 of Set 6 | grand baie
# Processing Record 8 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 6 | flinders
# Processing Record 10 of Set 6 | karpinsk
# Processing Record 11 of Set 6 | pacific grove
# Processing Record 12 of Set 6 | san juan del sur
# Processing Record 13 of Set 6 | dulce grande
# Processing Record 14 of Set 6 | mackenzie
# Processing Record 15 of Set 6 | yerbogachen
# Processing Record 16 of Set 6 | abu dhabi
# Processing Record 17 of Set 6 | rawson
# Processing Record 18 of Set 6 | saint andrews
# Processing Record 19 of Set 6 | umm kaddadah
# Processing Record 20 of Set 6 | garm
# City not found. Skipping...
# Processing Record 21 of Set 6 | talnakh
# Processing Record 22 of Set 6 | nuevitas
# Processing Record 23 of Set 6 | ippy
# Processing Record 24 of Set 6 | mandaguacu
# Processing Record 25 of Set 6 | beringovskiy
# Processing Record 26 of Set 6 | khaniotis
# Processing Record 27 of Set 6 | namibe
# Processing Record 28 of Set 6 | bonthe
# Processing Record 29 of Set 6 | lagoa
# Processing Record 30 of Set 6 | fare
# Processing Record 31 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 6 | bambari
# Processing Record 33 of Set 6 | tahta
# Processing Record 34 of Set 6 | solikamsk
# Processing Record 35 of Set 6 | severo-kurilsk
# Processing Record 36 of Set 6 | chapais
# Processing Record 37 of Set 6 | harper
# Processing Record 38 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 6 | djambala
# Processing Record 40 of Set 6 | varna
# Processing Record 41 of Set 6 | kirkconnel
# Processing Record 42 of Set 6 | portland
# Processing Record 43 of Set 6 | langsa
# Processing Record 44 of Set 6 | sergeyevka
# Processing Record 45 of Set 6 | port blair
# Processing Record 46 of Set 6 | noumea
# Processing Record 47 of Set 6 | vorontsovka
# Processing Record 48 of Set 6 | ust-ishim
# Processing Record 49 of Set 6 | sao gabriel da cachoeira
# Processing Record 50 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 7 | eureka
# Processing Record 2 of Set 7 | komsomolskiy
# Processing Record 3 of Set 7 | pemangkat
# Processing Record 4 of Set 7 | broome
# Processing Record 5 of Set 7 | moose factory
# Processing Record 6 of Set 7 | bang saphan
# Processing Record 7 of Set 7 | garowe
# Processing Record 8 of Set 7 | hofn
# Processing Record 9 of Set 7 | kemi
# Processing Record 10 of Set 7 | filadelfia
# Processing Record 11 of Set 7 | tsumeb
# Processing Record 12 of Set 7 | vila velha
# Processing Record 13 of Set 7 | xuddur
# Processing Record 14 of Set 7 | onoda
# Processing Record 15 of Set 7 | gaeta
# Processing Record 16 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 7 | copiapo
# Processing Record 18 of Set 7 | cody
# Processing Record 19 of Set 7 | coquimbo
# Processing Record 20 of Set 7 | batagay-alyta
# Processing Record 21 of Set 7 | yeppoon
# Processing Record 22 of Set 7 | mareeba
# Processing Record 23 of Set 7 | goya
# Processing Record 24 of Set 7 | shellbrook
# Processing Record 25 of Set 7 | faya
# Processing Record 26 of Set 7 | nantucket
# Processing Record 27 of Set 7 | naze
# Processing Record 28 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 7 | sorland
# Processing Record 30 of Set 7 | ravar
# Processing Record 31 of Set 7 | urdoma
# Processing Record 32 of Set 7 | uvalde
# Processing Record 33 of Set 7 | tucuman
# Processing Record 34 of Set 7 | margate
# Processing Record 35 of Set 7 | ukiah
# Processing Record 36 of Set 7 | ambanja
# Processing Record 37 of Set 7 | gamba
# Processing Record 38 of Set 7 | moyobamba
# Processing Record 39 of Set 7 | aitape
# Processing Record 40 of Set 7 | puerto narino
# Processing Record 41 of Set 7 | garden city
# Processing Record 42 of Set 7 | dzilam gonzalez
# Processing Record 43 of Set 7 | evensk
# Processing Record 44 of Set 7 | larap
# Processing Record 45 of Set 7 | san jose
# Processing Record 46 of Set 7 | matara
# Processing Record 47 of Set 7 | novyye burasy
# Processing Record 48 of Set 7 | sayanskiy
# City not found. Skipping...
# Processing Record 49 of Set 7 | port lincoln
# Processing Record 50 of Set 7 | najran
# Processing Record 1 of Set 8 | arlit
# Processing Record 2 of Set 8 | zyryanka
# Processing Record 3 of Set 8 | vidim
# Processing Record 4 of Set 8 | bosaso
# Processing Record 5 of Set 8 | sangmelima
# Processing Record 6 of Set 8 | pisco
# Processing Record 7 of Set 8 | meulaboh
# Processing Record 8 of Set 8 | kasongo
# Processing Record 9 of Set 8 | upernavik
# Processing Record 10 of Set 8 | koumac
# Processing Record 11 of Set 8 | jalu
# Processing Record 12 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 8 | porto belo
# Processing Record 14 of Set 8 | bagh
# Processing Record 15 of Set 8 | guararapes
# Processing Record 16 of Set 8 | tonantins
# Processing Record 17 of Set 8 | gualeguay
# Processing Record 18 of Set 8 | oeiras do para
# Processing Record 19 of Set 8 | vardo
# Processing Record 20 of Set 8 | ugoofaaru
# Processing Record 21 of Set 8 | luderitz
# Processing Record 22 of Set 8 | hami
# Processing Record 23 of Set 8 | balaghat
# Processing Record 24 of Set 8 | bonavista
# Processing Record 25 of Set 8 | nome
# Processing Record 26 of Set 8 | zhigansk
# Processing Record 27 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 28 of Set 8 | foso
# Processing Record 29 of Set 8 | richards bay
# Processing Record 30 of Set 8 | lahaina
# Processing Record 31 of Set 8 | barra patuca
# Processing Record 32 of Set 8 | kirkwood
# Processing Record 33 of Set 8 | tainan
# Processing Record 34 of Set 8 | qaanaaq
# Processing Record 35 of Set 8 | baykit
# Processing Record 36 of Set 8 | dunmore east
# Processing Record 37 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 8 | nata
# Processing Record 39 of Set 8 | hasaki
# Processing Record 40 of Set 8 | itarema
# Processing Record 41 of Set 8 | padang
# Processing Record 42 of Set 8 | uyuni
# Processing Record 43 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 8 | port hedland
# Processing Record 45 of Set 8 | ulladulla
# Processing Record 46 of Set 8 | boca do acre
# Processing Record 47 of Set 8 | maceio
# Processing Record 48 of Set 8 | chara
# Processing Record 49 of Set 8 | lompoc
# Processing Record 50 of Set 8 | darnah
# Processing Record 1 of Set 9 | praia
# Processing Record 2 of Set 9 | malbug
# Processing Record 3 of Set 9 | vila do maio
# Processing Record 4 of Set 9 | aras
# Processing Record 5 of Set 9 | uruguaiana
# Processing Record 6 of Set 9 | veshenskaya
# Processing Record 7 of Set 9 | ahipara
# Processing Record 8 of Set 9 | asau
# Processing Record 9 of Set 9 | karratha
# Processing Record 10 of Set 9 | palang
# Processing Record 11 of Set 9 | kasra
# City not found. Skipping...
# Processing Record 12 of Set 9 | bokoro
# Processing Record 13 of Set 9 | tarakan
# Processing Record 14 of Set 9 | carnarvon
# Processing Record 15 of Set 9 | katherine
# Processing Record 16 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 9 | joshimath
# Processing Record 18 of Set 9 | gorontalo
# Processing Record 19 of Set 9 | mehamn
# Processing Record 20 of Set 9 | pankrushikha
# Processing Record 21 of Set 9 | tongzi
# Processing Record 22 of Set 9 | lokosovo
# Processing Record 23 of Set 9 | mmabatho
# Processing Record 24 of Set 9 | wattegama
# Processing Record 25 of Set 9 | kungurtug
# Processing Record 26 of Set 9 | ilulissat
# Processing Record 27 of Set 9 | varzea da palma
# Processing Record 28 of Set 9 | honiara
# Processing Record 29 of Set 9 | machilipatnam
# Processing Record 30 of Set 9 | mount gambier
# Processing Record 31 of Set 9 | kalabo
# Processing Record 32 of Set 9 | farah
# Processing Record 33 of Set 9 | san roque
# Processing Record 34 of Set 9 | hearst
# Processing Record 35 of Set 9 | kahului
# Processing Record 36 of Set 9 | irbil
# Processing Record 37 of Set 9 | luganville
# Processing Record 38 of Set 9 | scarborough
# Processing Record 39 of Set 9 | chizhou
# Processing Record 40 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 9 | monte patria
# Processing Record 42 of Set 9 | alofi
# Processing Record 43 of Set 9 | inuvik
# Processing Record 44 of Set 9 | khanpur
# Processing Record 45 of Set 9 | oistins
# Processing Record 46 of Set 9 | do gonbadan
# Processing Record 47 of Set 9 | zhigalovo
# Processing Record 48 of Set 9 | bandarbeyla
# Processing Record 49 of Set 9 | shubarkuduk
# Processing Record 50 of Set 9 | sabang
# Processing Record 1 of Set 10 | zolotkovo
# Processing Record 2 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 10 | faanui
# Processing Record 4 of Set 10 | charters towers
# Processing Record 5 of Set 10 | lorengau
# Processing Record 6 of Set 10 | iqaluit
# Processing Record 7 of Set 10 | san cristobal
# Processing Record 8 of Set 10 | katangli
# Processing Record 9 of Set 10 | lukiv
# Processing Record 10 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 11 of Set 10 | roald
# Processing Record 12 of Set 10 | pokanayevka
# City not found. Skipping...
# Processing Record 13 of Set 10 | puerto pinasco
# City not found. Skipping...
# Processing Record 14 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 10 | vao
# Processing Record 16 of Set 10 | shimoda
# Processing Record 17 of Set 10 | naryan-mar
# Processing Record 18 of Set 10 | millinocket
# Processing Record 19 of Set 10 | sarkand
# Processing Record 20 of Set 10 | nsanje
# Processing Record 21 of Set 10 | gobabis
# Processing Record 22 of Set 10 | alyangula
# Processing Record 23 of Set 10 | riacho de santana
# Processing Record 24 of Set 10 | morondava
# Processing Record 25 of Set 10 | half moon bay
# Processing Record 26 of Set 10 | innisfail
# Processing Record 27 of Set 10 | sakakah
# Processing Record 28 of Set 10 | kavaratti
# Processing Record 29 of Set 10 | san carlos
# Processing Record 30 of Set 10 | bahia honda
# Processing Record 31 of Set 10 | mogadishu
# Processing Record 32 of Set 10 | paine
# Processing Record 33 of Set 10 | contai
# Processing Record 34 of Set 10 | limaong
# Processing Record 35 of Set 10 | marzuq
# Processing Record 36 of Set 10 | lysa hora
# Processing Record 37 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 38 of Set 10 | matamoros
# Processing Record 39 of Set 10 | tias
# Processing Record 40 of Set 10 | portmarnock
# Processing Record 41 of Set 10 | reconquista
# Processing Record 42 of Set 10 | rosetta
# Processing Record 43 of Set 10 | campbell river
# Processing Record 44 of Set 10 | welkom
# Processing Record 45 of Set 10 | omboue
# Processing Record 46 of Set 10 | shenzhen
# Processing Record 47 of Set 10 | suntar
# Processing Record 48 of Set 10 | cururupu
# Processing Record 49 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 11 | bandiagara
# Processing Record 2 of Set 11 | douentza
# Processing Record 3 of Set 11 | les cayes
# Processing Record 4 of Set 11 | ban nahin
# Processing Record 5 of Set 11 | black river
# Processing Record 6 of Set 11 | kuruman
# Processing Record 7 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 11 | bathsheba
# Processing Record 9 of Set 11 | puerto baquerizo moreno
# Processing Record 10 of Set 11 | syamzha
# Processing Record 11 of Set 11 | mecca
# Processing Record 12 of Set 11 | juneau
# Processing Record 13 of Set 11 | odweyne
# Processing Record 14 of Set 11 | kieta
# Processing Record 15 of Set 11 | canby
# Processing Record 16 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 11 | saint-georges
# Processing Record 18 of Set 11 | jiangyou
# Processing Record 19 of Set 11 | houston
# Processing Record 20 of Set 11 | jacareacanga
# Processing Record 21 of Set 11 | moranbah
# Processing Record 22 of Set 11 | bojnurd
# Processing Record 23 of Set 11 | sassandra
# Processing Record 24 of Set 11 | tocopilla
# Processing Record 25 of Set 11 | sao mateus
# Processing Record 26 of Set 11 | cartagena del chaira
# Processing Record 27 of Set 11 | yulara
# Processing Record 28 of Set 11 | obo
# Processing Record 29 of Set 11 | port augusta
# Processing Record 30 of Set 11 | sandwick
# Processing Record 31 of Set 11 | semey
# Processing Record 32 of Set 11 | the pas
# Processing Record 33 of Set 11 | ca mau
# Processing Record 34 of Set 11 | ponta delgada
# Processing Record 35 of Set 11 | angoche
# Processing Record 36 of Set 11 | saskylakh
# Processing Record 37 of Set 11 | sampit
# Processing Record 38 of Set 11 | maksatikha
# Processing Record 39 of Set 11 | saalfeld
# Processing Record 40 of Set 11 | geraldton
# Processing Record 41 of Set 11 | sao joao da barra
# Processing Record 42 of Set 11 | port hardy
# Processing Record 43 of Set 11 | tomatlan
# Processing Record 44 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 11 | vila
# Processing Record 46 of Set 11 | nahariyya
# Processing Record 47 of Set 11 | talakan
# Processing Record 48 of Set 11 | vung tau
# Processing Record 49 of Set 11 | nola
# Processing Record 50 of Set 11 | salamiyah
# Processing Record 1 of Set 12 | sao felix do xingu
# Processing Record 2 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 3 of Set 12 | miandoab
# Processing Record 4 of Set 12 | gizo
# Processing Record 5 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 12 | quatre cocos
# Processing Record 7 of Set 12 | esil
# Processing Record 8 of Set 12 | vostok
# Processing Record 9 of Set 12 | masakin
# Processing Record 10 of Set 12 | katha
# City not found. Skipping...
# Processing Record 11 of Set 12 | polunochnoye
# Processing Record 12 of Set 12 | raudeberg
# Processing Record 13 of Set 12 | cicero dantas
# Processing Record 14 of Set 12 | lukovetskiy
# Processing Record 15 of Set 12 | wawa
# Processing Record 16 of Set 12 | pueblo
# Processing Record 17 of Set 12 | kattivakkam
# Processing Record 18 of Set 12 | fort nelson
# Processing Record 19 of Set 12 | vallenar
# Processing Record 20 of Set 12 | walvis bay
# Processing Record 21 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 12 | dolores
# Processing Record 23 of Set 12 | bradford
# Processing Record 24 of Set 12 | strezhevoy
# Processing Record 25 of Set 12 | road town
# Processing Record 26 of Set 12 | chengde
# Processing Record 27 of Set 12 | nakamura
# Processing Record 28 of Set 12 | salur
# Processing Record 29 of Set 12 | kargasok
# Processing Record 30 of Set 12 | basi
# Processing Record 31 of Set 12 | santa cruz de tenerife
# Processing Record 32 of Set 12 | pitkyaranta
# Processing Record 33 of Set 12 | benghazi
# Processing Record 34 of Set 12 | odemis
# City not found. Skipping...
# Processing Record 35 of Set 12 | koscierzyna
# Processing Record 36 of Set 12 | caracuaro
# Processing Record 37 of Set 12 | taoudenni
# Processing Record 38 of Set 12 | altdorf
# Processing Record 39 of Set 12 | waingapu
# Processing Record 40 of Set 12 | awassa
# Processing Record 41 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 12 | sidhi
# Processing Record 43 of Set 12 | avera
# Processing Record 44 of Set 12 | eustis
# Processing Record 45 of Set 12 | cairns
# Processing Record 46 of Set 12 | yar-sale
# Processing Record 47 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 48 of Set 12 | korem
# Processing Record 49 of Set 12 | sumenep
# Processing Record 50 of Set 12 | samagaltay
# Processing Record 1 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 13 | san miguelito
# Processing Record 3 of Set 13 | mrakovo
# Processing Record 4 of Set 13 | ayan
# Processing Record 5 of Set 13 | ixtapa
# Processing Record 6 of Set 13 | marsa matruh
# Processing Record 7 of Set 13 | nushki
# Processing Record 8 of Set 13 | nelson bay
# Processing Record 9 of Set 13 | glubokoe
# City not found. Skipping...
# Processing Record 10 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 13 | kon tum
# Processing Record 12 of Set 13 | belyy yar
# Processing Record 13 of Set 13 | zharkent
# Processing Record 14 of Set 13 | cocachacra
# Processing Record 15 of Set 13 | kruisfontein
# Processing Record 16 of Set 13 | saint-pierre
# Processing Record 17 of Set 13 | shillong
# Processing Record 18 of Set 13 | synya
# Processing Record 19 of Set 13 | nioro
# Processing Record 20 of Set 13 | khandbari
# Processing Record 21 of Set 13 | bonfim
# Processing Record 22 of Set 13 | ambon
# Processing Record 23 of Set 13 | nassau
# Processing Record 24 of Set 13 | gold coast
# Processing Record 25 of Set 13 | vestmannaeyjar
# Processing Record 26 of Set 13 | porto torres
# Processing Record 27 of Set 13 | pecos
# Processing Record 28 of Set 13 | diffa
# Processing Record 29 of Set 13 | bollnas
# Processing Record 30 of Set 13 | rio gallegos
# Processing Record 31 of Set 13 | marawi
# Processing Record 32 of Set 13 | dharchula
# Processing Record 33 of Set 13 | calatayud
# Processing Record 34 of Set 13 | ketchikan
# Processing Record 35 of Set 13 | cabedelo
# Processing Record 36 of Set 13 | moshenskoye
# Processing Record 37 of Set 13 | temir
# Processing Record 38 of Set 13 | hanchuan
# Processing Record 39 of Set 13 | oytal
# Processing Record 40 of Set 13 | lovozero
# Processing Record 41 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 13 | beitbridge
# Processing Record 43 of Set 13 | payo
# Processing Record 44 of Set 13 | haines junction
# Processing Record 45 of Set 13 | tailai
# Processing Record 46 of Set 13 | atambua
# Processing Record 47 of Set 13 | vila franca do campo
# Processing Record 48 of Set 13 | waipawa
# Processing Record 49 of Set 13 | tura
# Processing Record 50 of Set 13 | boa esperanca
# Processing Record 1 of Set 14 | bengkulu
# Processing Record 2 of Set 14 | kaohsiung
# Processing Record 3 of Set 14 | provost
# Processing Record 4 of Set 14 | te anau
# Processing Record 5 of Set 14 | nagaoka
# Processing Record 6 of Set 14 | fort portal
# Processing Record 7 of Set 14 | minuri
# Processing Record 8 of Set 14 | lumphat
# Processing Record 9 of Set 14 | kailua
# Processing Record 10 of Set 14 | shahr-e babak
# Processing Record 11 of Set 14 | kiruna
# Processing Record 12 of Set 14 | warrnambool
# Processing Record 13 of Set 14 | laguna
# Processing Record 14 of Set 14 | celestun
# Processing Record 15 of Set 14 | pio ix
# Processing Record 16 of Set 14 | leningradskiy
# Processing Record 17 of Set 14 | rudbar
# Processing Record 18 of Set 14 | ilo
# Processing Record 19 of Set 14 | severo-yeniseyskiy
# Processing Record 20 of Set 14 | rogers
# Processing Record 21 of Set 14 | mnogovershinnyy
# Processing Record 22 of Set 14 | kyaukse
# Processing Record 23 of Set 14 | grivenskaya
# Processing Record 24 of Set 14 | hokitika
# Processing Record 25 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 26 of Set 14 | shadrinsk
# Processing Record 27 of Set 14 | lincoln
# Processing Record 28 of Set 14 | banda aceh
# Processing Record 29 of Set 14 | iracoubo
# Processing Record 30 of Set 14 | tabou
# Processing Record 31 of Set 14 | altamont
# Processing Record 32 of Set 14 | kosonsoy
# Processing Record 33 of Set 14 | nossa senhora da gloria
# Processing Record 34 of Set 14 | dicabisagan
# Processing Record 35 of Set 14 | yebaishou
# Processing Record 36 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 14 | novo aripuana
# Processing Record 38 of Set 14 | ilebo
# Processing Record 39 of Set 14 | saint-augustin
# Processing Record 40 of Set 14 | san policarpo
# Processing Record 41 of Set 14 | vanavara
# Processing Record 42 of Set 14 | aksarka
# Processing Record 43 of Set 14 | novolvovsk
# City not found. Skipping...
# Processing Record 44 of Set 14 | pak phanang
# Processing Record 45 of Set 14 | qaqortoq
# Processing Record 46 of Set 14 | surovikino
# Processing Record 47 of Set 14 | bhanvad
# Processing Record 48 of Set 14 | aksu
# Processing Record 49 of Set 14 | hamilton
# Processing Record 50 of Set 14 | eslov
# Processing Record 1 of Set 15 | sayat
# Processing Record 2 of Set 15 | cabra
# Processing Record 3 of Set 15 | ostersund
# Processing Record 4 of Set 15 | phangnga
# Processing Record 5 of Set 15 | mindelo
# Processing Record 6 of Set 15 | san fernando
# Processing Record 7 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 8 of Set 15 | minab
# Processing Record 9 of Set 15 | baragua
# Processing Record 10 of Set 15 | hadejia
# Processing Record 11 of Set 15 | mormugao
# Processing Record 12 of Set 15 | talcahuano
# Processing Record 13 of Set 15 | comodoro rivadavia
# Processing Record 14 of Set 15 | savinka
# Processing Record 15 of Set 15 | abalak
# Processing Record 16 of Set 15 | mandurah
# Processing Record 17 of Set 15 | atasu
# Processing Record 18 of Set 15 | iquitos
# Processing Record 19 of Set 15 | turukhansk
# Processing Record 20 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 21 of Set 15 | yenagoa
# Processing Record 22 of Set 15 | sunndalsora
# Processing Record 23 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 15 | choix
# Processing Record 25 of Set 15 | beboto
# Processing Record 26 of Set 15 | pringsewu
# Processing Record 27 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 15 | maiduguri
# Processing Record 29 of Set 15 | jiuquan
# Processing Record 30 of Set 15 | samana
# Processing Record 31 of Set 15 | esna
# Processing Record 32 of Set 15 | saint combs
# City not found. Skipping...
# Processing Record 33 of Set 15 | bayan
# Processing Record 34 of Set 15 | rjukan
# Processing Record 35 of Set 15 | verkhoyansk
# Processing Record 36 of Set 15 | lucera
# Processing Record 37 of Set 15 | eregli
# Processing Record 38 of Set 15 | visnes
# Processing Record 39 of Set 15 | waddan
# Processing Record 40 of Set 15 | bahia blanca
# Processing Record 41 of Set 15 | kutahya
# Processing Record 42 of Set 15 | norrkoping
# Processing Record 43 of Set 15 | zelenyy bor
# Processing Record 44 of Set 15 | miraflores
# Processing Record 45 of Set 15 | bakel
# Processing Record 46 of Set 15 | merano
# Processing Record 47 of Set 15 | rocha
# Processing Record 48 of Set 15 | saint george
# Processing Record 49 of Set 15 | mao
# Processing Record 50 of Set 15 | praia da vitoria
# Processing Record 1 of Set 16 | high rock
# Processing Record 2 of Set 16 | oak ridge
# Processing Record 3 of Set 16 | nanortalik
# Processing Record 4 of Set 16 | tazovskiy
# Processing Record 5 of Set 16 | sao gabriel
# Processing Record 6 of Set 16 | jomalig
# City not found. Skipping...
# Processing Record 7 of Set 16 | baracoa
# Processing Record 8 of Set 16 | mobaye
# Processing Record 9 of Set 16 | seddon
# Processing Record 10 of Set 16 | marfino
# Processing Record 11 of Set 16 | stary sacz
# Processing Record 12 of Set 16 | uyemskiy
# Processing Record 13 of Set 16 | tromso
# Processing Record 14 of Set 16 | aleksandrov gay
# Processing Record 15 of Set 16 | yuksekova
# Processing Record 16 of Set 16 | shelburne
# Processing Record 17 of Set 16 | egvekinot
# Processing Record 18 of Set 16 | luanda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 700

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Hermanus -34.4187   19.2345     57.67        69          40        4.83
# 1        Vaini -21.2000 -175.2000     84.36        84          75        9.22
# 2   Baker City  44.7749 -117.8344     24.51        58           0        4.61
# 3     Ismailia  30.6043   32.2723     61.32        75          11        7.87
# 4      Rikitea -23.1203 -134.9692     74.91        77           7       12.75
# 5    Hithadhoo  -0.6000   73.0833     82.69        71         100       11.79
# 6    Boguchany  58.3814   97.4531    -12.48       100          70        3.78
# 7  Port Alfred -33.5906   26.8910     62.19        91         100        6.93
# 8        Airai  -8.9266  125.4092     76.71        39          96        0.87
# 9    Havoysund  70.9963   24.6622     28.63        78          26        9.69
#
#   Country Current Description
# 0      ZA    scattered clouds
# 1      TO       broken clouds
# 2      US           clear sky
# 3      EG          few clouds
# 4      PF           clear sky
# 5      MV          light rain
# 6      RU       broken clouds
# 7      ZA     overcast clouds
# 8      TL     overcast clouds
# 9      NO    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city = city_data_df["City"]
country = city_data_df["Country"]
lats = city_data_df["Lat"]
lngs = city_data_df["Lng"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
description = city_data_df["Current Description"]

# Recreate the DataFrame by using the new column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Display sample data
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Hermanus      ZA -34.4187   19.2345     57.67        69
# 1              Vaini      TO -21.2000 -175.2000     84.36        84
# 2         Baker City      US  44.7749 -117.8344     24.51        58
# 3           Ismailia      EG  30.6043   32.2723     61.32        75
# 4            Rikitea      PF -23.1203 -134.9692     74.91        77
# ..               ...     ...      ...       ...       ...       ...
# 695  Aleksandrov Gay      RU  50.1470   48.5704     12.63        63
# 696        Yuksekova      TR  37.5736   44.2872     28.58        92
# 697        Shelburne      CA  44.0787  -80.2041     29.75        71
# 698        Egvekinot      RU  66.3167 -179.1667     15.06        91
# 699           Luanda      AO  -8.8368   13.2343     78.80        83
#
#      Cloudiness  Wind Speed Current Description
# 0            40        4.83    scattered clouds
# 1            75        9.22       broken clouds
# 2             0        4.61           clear sky
# 3            11        7.87          few clouds
# 4             7       12.75           clear sky
# ..          ...         ...                 ...
# 695           0        9.31           clear sky
# 696          35        4.12    scattered clouds
# 697          96       14.94     overcast clouds
# 698         100       16.44                snow
# 699          40        5.75    scattered clouds
#
# [700 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
